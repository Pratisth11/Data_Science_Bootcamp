# %%
# first thing from previous case study

# if a csv exists that means previous records are there

# else No records exists

# if records Exists we need to read them and load them in the lists that we need to use for case study

# At the end when user says Bye! that is 7th option save whatever data we have in the list to CSV

# %%
# 1st case study pandas
import os
import pandas as pd

if os.path.exists("abcd.csv"):
  df=pd.read_csv("abcd.csv")
  all_values=list(df["sum"])
  print("ALL VALUES ",all_values)
  new_element=0
  for k in all_values:
    new_element=new_element+k
  all_values.append(new_element)
  dict_sum={"sum":all_values}
  new_df=pd.DataFrame(dict_sum)
  new_df.to_csv("abcd.csv",index=False)
else:
  df=pd.DataFrame({"sum":[1]})
  df.to_csv("abcd.csv",index=False)


#refer to ems

# %%
import os
import pandas as pd

#info = input("enter the info/name: ")
csv_file =  'data.csv'
if os.path.exists(csv_file):
  print('hello')
else:
  print('hi')
  
#else statement not checked for the existance of the file 
'''
with open('new file.csv', mode = 'w') as csvfile:
  for rows in csv_file:
    field_names = rows
'''
# Out:
# hi
# "\nwith open('new file.csv', mode = 'w') as csvfile:\n  for rows in csv_file:\n    field_names = rows\n"

# %%
import numpy as np
import matplotlib.pyplot as plt
